# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# e:\Project\Japan_Housing_Prices\src

# %%
df = pd.read_csv(r"E:\Project\Japan_Housing_Prices\data\raw\All_prefectures_buildings_with_migration.csv")

# %%
print(df.head())
# Out:
#                                   Type  City,Town,Ward,Village code  \
# 0  Residential Land(Land and Building)                        20201
# 1  Residential Land(Land and Building)                        20201
# 2  Residential Land(Land and Building)                        20201
# 3  Residential Land(Land and Building)                        20201
# 4  Residential Land(Land and Building)                        20201
#
#           Prefecture     Location  TotalTransactionValue  Area  Frontage  \
# 0  Nagano Prefecture  Nagano City               27000000   175       9.0
# 1  Nagano Prefecture  Nagano City               27000000   125       9.0
# 2  Nagano Prefecture  Nagano City                6500000    90      10.0
# 3  Nagano Prefecture  Nagano City               27000000   135       8.5
# 4  Nagano Prefecture  Nagano City               67000000   340       4.0
#
#    TotalFloorArea  ConstructionYear  BuildingCoverageRatio  ...  \
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1339147 entries, 0 to 1339146
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count    Dtype
# ---  ------                          --------------    -----
#  0   Type                            1339147 non-null  str
#  1   City,Town,Ward,Village code     1339147 non-null  int64
#  2   Prefecture                      1339147 non-null  str
#  3   Location                        1339147 non-null  str
#  4   TotalTransactionValue           1339147 non-null  int64
#  5   Area                            1339147 non-null  int64
#  6   Frontage                        1339147 non-null  float64
#  7   TotalFloorArea                  1339147 non-null  int64
#  8   ConstructionYear                1339147 non-null  int64
#  9   BuildingCoverageRatio           1339147 non-null  float64
#  10  FloorAreaRatio                  1339147 non-null  float64
#  11  Quarter                         1339147 non-null  int64
# ...

# %%
print(df.describe())
# Out:
#        City,Town,Ward,Village code  TotalTransactionValue          Area  \
# count                 1.339147e+06           1.339147e+06  1.339147e+06
# mean                  1.946869e+04           3.208476e+07  1.964027e+02
# std                   1.089614e+04           7.252852e+07  1.816367e+02
# min                   1.101000e+03           1.000000e+02  1.000000e+01
# 25%                   1.220400e+04           1.300000e+07  1.050000e+02
# 50%                   1.510400e+04           2.500000e+07  1.550000e+02
# 75%                   2.721000e+04           3.700000e+07  2.200000e+02
# max                   4.732900e+04           3.100000e+10  2.000000e+03
#
#            Frontage  TotalFloorArea  ConstructionYear  BuildingCoverageRatio  \
# count  1.339147e+06    1.339147e+06      1.339147e+06           1.339147e+06
# mean   1.125173e+01    1.268709e+02      1.999299e+03           5.768001e+01
# std    6.091963e+00    1.348441e+02      1.772234e+01           8.871038e+00
# ...

# %%
print(df.duplicated().sum())
# Out:
# 1639

# %%
df.drop_duplicates(inplace=True)

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(os.listdir("../data/raw"))
# Out:
# ['All_prefectures_buildings_with_migration.csv']

# %%
df.to_csv(r"E:\Project\Japan_Housing_Prices\data\cleaned\cleaned.csv", index=False)
